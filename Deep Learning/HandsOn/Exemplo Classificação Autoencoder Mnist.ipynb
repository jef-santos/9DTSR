# %%
from keras.datasets import mnist
from keras.layers import Input, Dense
from keras.models import Model
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

#!pip install xgboost
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score, ConfusionMatrixDisplay
from sklearn.manifold import TSNE

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
X_train.shape, X_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28))

# %%
X_train = X_train.reshape(len(X_train), np.prod(X_train.shape[1:]))
X_test = X_test.reshape(len(X_test), np.prod(X_test.shape[1:]))
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
input_img= Input(shape=(784,))
encoded = Dense(units=32, activation='relu')(input_img)
decoded = Dense(units=784, activation='sigmoid')(encoded)

# %%
autoencoder=Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 784)            │        25,872 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,992 (199.19 KB)
#  Trainable params: 50,992 (199.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
encoder = Model(input_img, encoded)
encoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        25,120 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,120 (98.12 KB)
#  Trainable params: 25,120 (98.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
autoencoder.fit(X_train, X_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.0087 - loss: 0.3837 - val_accuracy: 0.0109 - val_loss: 0.1886
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.0110 - loss: 0.1796 - val_accuracy: 0.0107 - val_loss: 0.1538
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0103 - loss: 0.1492 - val_accuracy: 0.0096 - val_loss: 0.1334
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0110 - loss: 0.1317 - val_accuracy: 0.0111 - val_loss: 0.1213
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0110 - loss: 0.1206 - val_accuracy: 0.0116 - val_loss: 0.1134
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0106 - loss: 0.1133 - val_accuracy: 0.0123 - val_loss: 0.1076
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0106 - loss: 0.1075 - val_accuracy: 0.0133 - val_loss: 0.1032
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0110 - loss: 0.1035 - val_accuracy: 0.0124 - val_loss: 0.1000
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0119 - loss: 0.1007 - val_accuracy: 0.0122 - val_loss: 0.0976
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0110 - loss: 0.0985 - val_accuracy: 0.0106 - val_loss: 0.0961
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0109 - loss: 0.0971 - val_accuracy: 0.0117 - val_loss: 0.0949
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0112 - loss: 0.0963 - val_accuracy: 0.0124 - val_loss: 0.0942
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0111 - loss: 0.0954 - val_accuracy: 0.0125 - val_loss: 0.0937
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0115 - loss: 0.0949 - val_accuracy: 0.0116 - val_loss: 0.0934
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0119 - loss: 0.0946 - val_accuracy: 0.0132 - val_loss: 0.0931
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0112 - loss: 0.0942 - val_accuracy: 0.0121 - val_loss: 0.0928
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0112 - loss: 0.0940 - val_accuracy: 0.0125 - val_loss: 0.0927
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0104 - loss: 0.0941 - val_accuracy: 0.0126 - val_loss: 0.0926
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0111 - loss: 0.0937 - val_accuracy: 0.0120 - val_loss: 0.0924
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0113 - loss: 0.0937 - val_accuracy: 0.0134 - val_loss: 0.0923
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0109 - loss: 0.0936 - val_accuracy: 0.0133 - val_loss: 0.0922
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0118 - loss: 0.0936 - val_accuracy: 0.0125 - val_loss: 0.0922
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0126 - loss: 0.0936 - val_accuracy: 0.0127 - val_loss: 0.0921
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0120 - loss: 0.0933 - val_accuracy: 0.0125 - val_loss: 0.0920
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0116 - loss: 0.0931 - val_accuracy: 0.0129 - val_loss: 0.0920
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0121 - loss: 0.0932 - val_accuracy: 0.0134 - val_loss: 0.0919
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0113 - loss: 0.0934 - val_accuracy: 0.0131 - val_loss: 0.0919
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0121 - loss: 0.0933 - val_accuracy: 0.0126 - val_loss: 0.0918
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0112 - loss: 0.0931 - val_accuracy: 0.0130 - val_loss: 0.0918
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0121 - loss: 0.0931 - val_accuracy: 0.0129 - val_loss: 0.0917
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0119 - loss: 0.0932 - val_accuracy: 0.0122 - val_loss: 0.0917
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0120 - loss: 0.0930 - val_accuracy: 0.0123 - val_loss: 0.0917
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0116 - loss: 0.0929 - val_accuracy: 0.0138 - val_loss: 0.0917
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0124 - loss: 0.0929 - val_accuracy: 0.0134 - val_loss: 0.0917
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0123 - loss: 0.0930 - val_accuracy: 0.0122 - val_loss: 0.0917
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0117 - loss: 0.0929 - val_accuracy: 0.0130 - val_loss: 0.0917
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0115 - loss: 0.0929 - val_accuracy: 0.0137 - val_loss: 0.0916
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0117 - loss: 0.0930 - val_accuracy: 0.0126 - val_loss: 0.0917
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0123 - loss: 0.0929 - val_accuracy: 0.0131 - val_loss: 0.0917
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0118 - loss: 0.0928 - val_accuracy: 0.0139 - val_loss: 0.0916
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0119 - loss: 0.0929 - val_accuracy: 0.0122 - val_loss: 0.0915
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0125 - loss: 0.0927 - val_accuracy: 0.0123 - val_loss: 0.0916
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0127 - loss: 0.0927 - val_accuracy: 0.0140 - val_loss: 0.0915
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0121 - loss: 0.0926 - val_accuracy: 0.0142 - val_loss: 0.0915
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0122 - loss: 0.0927 - val_accuracy: 0.0125 - val_loss: 0.0916
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0119 - loss: 0.0926 - val_accuracy: 0.0123 - val_loss: 0.0915
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0121 - loss: 0.0927 - val_accuracy: 0.0128 - val_loss: 0.0915
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0125 - loss: 0.0926 - val_accuracy: 0.0122 - val_loss: 0.0916
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.0128 - loss: 0.0925 - val_accuracy: 0.0120 - val_loss: 0.0915
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.0120 - loss: 0.0927 - val_accuracy: 0.0118 - val_loss: 0.0915

# %%
encoded_imgs = encoder.predict(X_test)
predicted = autoencoder.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
encoded_imgs.shape
# Out:
# (10000, 32)

# %%
predicted.shape
# Out:
# (10000, 784)

# %%
plt.figure(figsize=(40, 4))
for i in range(10):
    # display original
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display encoded image
    ax = plt.subplot(3, 20, i + 1 + 20)
    plt.imshow(encoded_imgs[i].reshape(8,4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    # display reconstruction
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)



plt.show()

# %%
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print(X_train_encoded.shape)
print(X_test_encoded.shape)
# Out:
# (60000, 32)
# (10000, 32)

# %% [markdown]
# # Processo de Classificaçao com Random Forest

# %%
modelRf = RandomForestClassifier()
modelRf.fit(X_train_encoded, y_train)
y_pred = modelRf.predict(X_test_encoded)

# %%
print(classification_report(y_test, y_pred))

print(accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       980
#            1       0.98      0.99      0.98      1135
#            2       0.95      0.95      0.95      1032
#            3       0.93      0.94      0.94      1010
#            4       0.94      0.96      0.95       982
#            5       0.95      0.91      0.93       892
#            6       0.96      0.98      0.97       958
#            7       0.95      0.93      0.94      1028
#            8       0.90      0.92      0.91       974
#            9       0.93      0.91      0.92      1009
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
#
# 0.9458

# %%
fig, ax = plt.subplots(figsize=(10, 10))

cm = confusion_matrix(y_test, y_pred, labels=modelRf.classes_, normalize = 'true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=modelRf.classes_)

disp.plot(ax = ax)
plt.show()

# %% [markdown]
# # Exemplo de Data Visualization a partir da camada Coded do Autoencoder

# %%
tsne = TSNE(n_iter=2000)
X_embedded_tsne = tsne.fit_transform(X_test_encoded)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
sns.set(rc={'figure.figsize':(20,10)})
palette = sns.color_palette("bright", 10)
sns.scatterplot(x = X_embedded_tsne[:,0], y = X_embedded_tsne[:,1], hue=y_test, legend='full', palette=palette)
# Out:
# <Axes: >

# %%
X_embedded_tsne.shape
# Out:
# (10000, 2)
