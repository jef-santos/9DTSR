# %% [markdown]
# Os valores [(-1, 0), (1, 0), (0, -1), (0, 1)] representam as alterações nas coordenadas (x, y) em um grid, e cada tupla reflete um movimento específico. Vamos entender cada um deles:
#
# Movimento para Cima:
#
# Tupla: (−1,0)
#
# Ao mover para cima, você está diminuindo a coordenada x em 1 (ou seja,
# 𝑥
# −
# 1
# x−1) e mantendo a coordenada y inalterada (ou seja,
# 𝑦
# y).
# Efeito: Se você está em uma posição
# (
# 2
# ,
# 3
# )
# (2,3), ao aplicar
# (
# −
# 1
# ,
# 0
# )
# (−1,0), você se move para
# (
# 1
# ,
# 3
# )
# (1,3).
# Movimento para Baixo:
#
# Tupla: (1,0)
#
# Ao mover para baixo, você está aumentando a coordenada x em 1 (ou seja,
# 𝑥
# +
# 1
# x+1) e mantendo a coordenada y inalterada.
# Efeito: Se você está em
# (
# 1
# ,
# 3
# )
# (1,3), ao aplicar
# (
# 1
# ,
# 0
# )
# (1,0), você se move para
# (
# 2
# ,
# 3
# )
# (2,3).
# Movimento para a Esquerda:
#
# Tupla: (0,−1)
#
# Ao mover para a esquerda, você está diminuindo a coordenada y em 1 (ou seja,
# 𝑦
# −
# 1
# y−1) e mantendo a coordenada x inalterada.
# Efeito: Se você está em
# (
# 2
# ,
# 3
# )
# (2,3), ao aplicar
# (
# 0
# ,
# −
# 1
# )
# (0,−1), você se move para
# (
# 2
# ,
# 2
# )
# (2,2).
# Movimento para a Direita:
#
# Tupla: (0,1)
#
# Ao mover para a direita, você está aumentando a coordenada y em 1 (ou seja,
# 𝑦
# +
# 1
# y+1) e mantendo a coordenada x inalterada.
# Efeito: Se você está em
# (
# 2
# ,
# 2
# )
# (2,2), ao aplicar
# (
# 0
# ,
# 1
# )
# (0,1), você se move para
# (
# 2
# ,
# 3
# )
# (2,3).
# Resumo:
# As alterações são sempre no formato
# (
# 𝑑
# 𝑥
# ,
# 𝑑
# 𝑦
# )
# (dx,dy), onde:
# 𝑑
# 𝑥
# dx representa a mudança na coordenada x (linha).
# 𝑑
# 𝑦
# dy representa a mudança na coordenada y (coluna).
# Portanto, a escolha dos valores é baseada na necessidade de mover-se na grade em relação à posição atual.

# %%
(0, 0) (0, 1) (0, 2) (0, 3)
(1, 0) (1, 1) (1, 2) (1, 3)
(2, 0) (2, 1) (2, 2) (2, 3)
(3, 0) (3, 1) (3, 2) (3, 3)

# %% [markdown]
# Para Cima: Mover de (1, 1) para (0, 1) significa
# (
# 1
# −
# 1
# ,
# 1
# )
# =
# (
# 0
# ,
# 1
# )
# (1−1,1)=(0,1).
#
# Para Baixo: Mover de (1, 1) para (2, 1) significa
# (
# 1
# +
# 1
# ,
# 1
# )
# =
# (
# 2
# ,
# 1
# )
# (1+1,1)=(2,1).
#
# Para Esquerda: Mover de (1, 1) para (1, 0) significa
# (
# 1
# ,
# 1
# −
# 1
# )
# =
# (
# 1
# ,
# 0
# )
# (1,1−1)=(1,0).
#
# Para Direita: Mover de (1, 1) para (1, 2) significa
# (
# 1
# ,
# 1
# +
# 1
# )
# =
# (
# 1
# ,
# 2
# )
# (1,1+1)=(1,2).
